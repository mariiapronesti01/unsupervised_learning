# %%
from Manifold_sculpting import *
from sklearn import datasets
import matplotlib.pyplot as plt

# %%
n_neighbors = 12
n_components = 2

# %% [markdown]
# ## SWISS ROLE

# %%
# Generate Swiss roll dataset
n = 1000
noise = 0.0
role_data, color = datasets.make_swiss_roll(n_samples = n, noise= noise, random_state=9)

# %%
role_manifold = Manifold_Sculpting(role_data, color=color)
# Out:
# data.shape[0]: 1000, type: <class 'int'>
# k: 12, type: <class 'int'>
# Preserved dimensions:  [0 1]
# Discarded dimensions:  [2]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 role_manifold = Manifold_Sculpting(role_data, color=color)
#
# File c:\Users\maria\Desktop\UniTS\Unsupervised learning\unsupervised_learning\Manifold_sculpting.py:70, in Manifold_Sculpting(data, k, n_components, n_iter, sigma, th, align, verbose, color, dim)
#      67         x_pca[j, dpres] /= sigma
#      69 # create queue of points and add a random point to the queue
# ---> 70 start_point = np.random.randint(0, x_pca.shape[0]).item()
#      71 q = deque([start_point])
#      73 # keep list of adjusted points
#
# AttributeError: 'int' object has no attribute 'item'
